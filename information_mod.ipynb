# %%
import re
import pathlib
import pandas as pd
import extract_module

import warnings
warnings.filterwarnings('ignore')

pathfile = r''
dataset_file = pathlib.Path(pathfile).joinpath('first_inspections')

# %%
import importlib

importlib.reload(extract_module)

pathfile = r""
file = pathlib.Path(pathfile).joinpath("first_inspections/12.txt")
f = open(file)
text = f.read()
dict_symp, dict_index = extract_module.extract(text)
for keys, values in dict_symp.items():
    print(keys, values)
# Out:
# Дата рождения 31.08.1981
# Дата осмотра 23.11.2016
# Дата заболевания 22.11.2016
# Возраст 35
# Болен дней 1
# Болен часов 24
# Возраст в днях 12868
# Время поступления 18:50
# Время заболевания 18:50
# рост 184
# вес 90
# IMT 26.58
# давление диаст 100
# давление сист 166
# температура поступления 39
# мах температура 39.6
# Т-Ан01 1
# Т-Ан03 2
# пол 1
# др заболевания в анамнезе поллиноз, холециститом, перелом, зуд, ангины, оспой, гастрит
# кем направлен 3
# побочное действие лекартсв None
# аллергическая реакция None
# озноб 1
# слабость 1
# вялость 1
# головная боль 1
# нарушение сна 0
# нарушение аппетита 0
# ломота 0
# тошнота 0
# нарушение сознания 0
# Судороги 0
# Парестезии 0
# эритема 1
# с четкими границами 1
# валик 0
# боль 1
# Гиперемия 1
# Отек 1
# Лимфаденит 1
# Лимфангит 0
# квартира, дом None
# контакт с зараженными None
# речная рыба 1
# провоцирущие факторы [3, 6, 7]
# предрасполагающие факторы None
# кол-во сопут заболеваний None
# соц категория 1
# сопутствующий диагноз None
# основной диагноз
#  А46 Рожа лица, локализованная, эритематозная, первичная, средней степени тяжести.
# пищевой анамнез None
# раневые ворота None
# аллергия на лекарства None
# клещ 0
# географический анамнез None
# вредные привычки 1
# домашние животные 0
# условия труда None
# избыточное питание None
# ППТ None
# ЛПТ None
# бытовые условия None
# питание None
# интоксикация 1
# ЧСС 128
# болезненность лимфоузлов 1
# увеличенность лимфоузлов 0
# размер лимфоузлов 1,5
# острое начало 1
# рана 0
# index:
# Дата рождения [44, 54)
# Дата осмотра [74, 84)
# Дата заболевания [274, 284)
# Возраст [55, 59)
# Болен дней None
# Болен часов None
# Возраст в днях None
# Время поступления [85, 90)
# Время заболевания [85, 90)
# рост [1627, 1635)
# вес [1616, 1622)
# IMT None
# давление диаст [2672, 2682)
# давление сист [2672, 2682)
# температура поступления [72, 74)
# мах температура None
# Т-Ан01 None
# Т-Ан03 None
# пол [35, 42)
# др заболевания в анамнезе [[221, 224), [708, 714), [836, 841), [843, 849), [875, 882), [892, 900), [1043, 1055), [1061, 1070)]
# кем направлен [592, 601)
# побочное действие лекартсв None
# аллергическая реакция None
# озноб [175, 182)
# слабость [215, 223)
# вялость [225, 235)
# головная боль [194, 207)
# нарушение сна None
# нарушение аппетита None
# ломота None
# тошнота None
# нарушение сознания None
# Судороги None
# Парестезии None
# эритема [440, 447)
# с четкими границами [1831, 1850)
# валик None
# боль [130, 134)
# Гиперемия [1717, 1726)
# Отек [450, 454)
# Лимфаденит []
# Лимфангит None
# квартира, дом None
# контакт с зараженными None
# речная рыба [22, 35)
# провоцирущие факторы [[998, 1012), [3587, 3601), [989, 996), [3603, 3616)]
# предрасполагающие факторы None
# кол-во сопут заболеваний None
# соц категория [956, 966)
# сопутствующий диагноз None
# основной диагноз [3678, 3762]
# пищевой анамнез None
# раневые ворота None
# аллергия на лекарства None
# клещ None
# географический анамнез None
# вредные привычки [1204, 1217)
# домашние животные []
# условия труда None
# избыточное питание None
# ППТ None
# ЛПТ None
# бытовые условия None
# питание None
# интоксикация [3473, 3485)
# ЧСС [2658, 2664)
# болезненность лимфоузлов [81, 91)
# увеличенность лимфоузлов None
# размер лимфоузлов [74, 77)
# острое начало [3419, 3433)

# %%
df = pd.DataFrame()
lst = []
docs = [file for file in dataset_file.iterdir() if file.suffix == '.txt']
for file in docs:
    print(file)
    lst.append(int(re.findall(r'\d+', str(file))[0]))
    f = open(file)
    text = f.read()
    dict_symp, dict_index = extract_module.extract(text)
    for keys,values in dict_symp.items():
        if type(values) is list:
            values = ','.join([str(elem) for elem in values])
        dict_symp[keys] = [values]
    df_patient = pd.DataFrame.from_dict(dict_symp)
    df = pd.concat([df, df_patient], ignore_index=True)
df.index = lst
df = df.sort_index()
df.head(10)
# Out:
# first_inspections/26.txt
# first_inspections/25.txt
# first_inspections/19.txt
# first_inspections/7.txt
# first_inspections/13.txt
# first_inspections/9.txt
# first_inspections/33.txt
# first_inspections/63.txt
# first_inspections/1.txt
# first_inspections/27.txt
# first_inspections/72.txt
# first_inspections/62.txt
# first_inspections/12.txt
# first_inspections/10.txt
# first_inspections/59.txt
# first_inspections/20.txt
# first_inspections/61.txt
# first_inspections/17.txt
# first_inspections/73.txt
# first_inspections/21.txt
# first_inspections/23.txt
# first_inspections/65.txt
# first_inspections/50.txt
# first_inspections/71.txt
# first_inspections/24.txt
# first_inspections/5.txt
# first_inspections/58.txt
# first_inspections/2.txt
# first_inspections/60.txt
# first_inspections/18.txt
# first_inspections/15.txt
# first_inspections/16.txt
# first_inspections/48.txt
# first_inspections/64.txt
# first_inspections/31.txt
# first_inspections/74.txt
#    Дата рождения Дата осмотра Дата заболевания  Возраст  Болен дней  \
# 1     28.03.1936   18.04.2016       15.04.2016       80           3
# 2     17.09.1985   29.03.2016         28.03.16       30           1
# 5     06.11.1937   29.01.2016       28.01.2016       78           1
# 7     21.06.1951   07.02.2016         06.02.16       64           1
# 9     01.01.1955   16.06.2016         13.06.16       61           3
# 10    11.05.1966   24.11.2016         21.11.16       50           3
# 12    31.08.1981   23.11.2016       22.11.2016       35           1
# 13          None   28.11.2016         25.11.16       65           3
# 15          None   21.12.2016         19.12.16       39           2
# 16          None   15.12.2016         13.12.16       58           2
#
#     Болен часов  Возраст в днях Время поступления Время заболевания  рост  \
# 1            72           29241             17:28             17:28   170
# 2            24           11151             13:13             13:13   170
# 5            24           28573             19:44             19:44   155
# 7             6           23607             00:47             18:00  None
# 9            72           22447             13:31             13:31  None
# 10           72           18460             12:53             12:53  None
# 12           24           12868             18:50             18:50   184
# 13           72           23725             09:57             09:57  None
# 15           48           14235             12:41             12:41   162
# 16           45           21170             14:53             17:00  None
#
#     ...       ЛПТ бытовые условия питание интоксикация   ЧСС  \
# 1   ...        13            None       1            1  None
# 2   ...      None               1       0            0  None
# 5   ...      None               1       0            0  None
# 7   ...      None            None    None            1    92
# 9   ...  12,13,14               1       0            0  None
# 10  ...      None               1       0            1  None
# 12  ...      None            None    None            1   128
# 13  ...      9,10               1       0            0  None
# 15  ...     2,2.1            None    None            1  None
# 16  ...      None               1       0            0  None
#
#     болезненность лимфоузлов  увеличенность лимфоузлов  размер лимфоузлов  \
# 1                          1                         1                1,5
# 2                          0                         0               None
# 5                       None                      None               None
# 7                          0                         0               None
# 9                          0                         0               None
# 10                         0                         0               None
# 12                         1                         0                1,5
# 13                         0                         0               None
# 15                         0                         0               None
# 16                         0                         0               None
#
#     острое начало рана
# 1               1    0
# 2               0    0
# 5               0    0
# 7               1    0
# 9               1    0
# 10              1    0
# 12              1    0
# 13              1    0
# 15              1    0
# 16              1    0
#
# [10 rows x 71 columns]

# %%
df.to_excel('parsing_with_clearcode3.xlsx')
